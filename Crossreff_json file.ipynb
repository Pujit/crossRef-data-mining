# %%
pwd
# Out:
# 'C:\\Users\\tu9419io'

# %%
import json
#url='https://api.crossref.org/works?query.author=Barry+Fields'
url='https://api.crossref.org/works?query.author=Rachel'
#url='https://api.crossref.org/works/10.1002/bin.2360060407'
#Rachel K. Youngblom
#url='https://api.crossref.org/works/10.25115/ejrep.v5i12.1277' https://api.crossref.org/works?query.title=room+at+the+bottom&query.author=richard+feynman\url='https://api.crossref.org/works/10.25115/ejrep.v5i12.1277' https://api.crossref.org/works?query.title=room+at+the+bottom&query.author=richard+feynman
#url='https://api.crossref.org/works?query.title=room+at+the+bottom&query.author=richard+feynman'
import urllib.request
data = urllib.request.urlopen(url)
#print(data)
result=data.read()

result=result.decode('utf8')

my_json = json.dumps(result)
my_json_loaded = json.loads(result)
print(json.dumps(my_json_loaded, indent=4))
# Out:
# {
#     "status": "ok",
#     "message-type": "work-list",
#     "message-version": "1.0.0",
#     "message": {
#         "facets": {},
#         "total-results": 105082,
#         "items": [
#             {
#                 "indexed": {
#                     "date-parts": [
#                         [
#                             2018,
#                             5,
#                             3
#                         ]
#                     ],
#                     "date-time": "2018-05-03T00:59:45Z",
#                     "timestamp": 1525309185313
#                 },
#                 "reference-count": 0,
#                 "publisher": "Wiley",
#                 "issue": "1",
#                 "license": [
#                     {
#                         "URL": "http://doi.wiley.com/10.1002/tdm_license_1.1",
#                         "start": {
#                             "date-parts": [
#                                 [
# ...
